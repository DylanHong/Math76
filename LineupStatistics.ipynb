# %%
#Import packages
import pandas as pd
import numpy as np
import time

# %%
#Get the Lakers team_id
from nba_api.stats.static import teams

nba_teams = teams.get_teams()

# Select the dictionary for the Pacers, which contains their team ID
lakers = [team for team in nba_teams if team['abbreviation'] == 'LAL'][0]
lakers_id = lakers['id']
print(f'lakers_id: {lakers_id}')
# Out:
# lakers_id: 1610612747

# %%
# Query for the last regular season game where the Lakers were playing
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.library.parameters import Season
from nba_api.stats.library.parameters import SeasonType

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=lakers_id,
                            season_nullable=Season.default,
                            season_type_nullable=SeasonType.regular)  

games_dict = gamefinder.get_normalized_dict()
games = games_dict['LeagueGameFinderResults']
game = games[0]
game_id = game['GAME_ID']
game_matchup = game['MATCHUP']

print("here")

print(f'Searching through {len(games)} game(s) for the game_id of {game_id} where {game_matchup}')
# Out:
# here
# Searching through 67 game(s) for the game_id of 0021800848 where LAL @ ATL

# %%
#Get all of this season's lakers games
print(games[0]["GAME_DATE"])
print(len(games))

#Get all the game dates
gamedates = []
for game in games: 
    gamedates.append(game["GAME_DATE"])
print(gamedates[:5])
print(len(gamedates[:]))
# Out:
# 2019-02-12
# 67
# ['2019-02-12', '2019-02-10', '2019-02-07', '2019-02-05', '2019-02-02']
# 67

# %%
from nba_api.stats.endpoints import teamdashlineups

#Combine dataframes
df = pd.DataFrame()
for date in gamedates[:5]:
    print(date)
    
    tempdf = teamdashlineups.TeamDashLineups(
        lakers_id,date_from_nullable = date, date_to_nullable = date).get_data_frames()[1]
    tempdf1 = tempdf[]
    print(len(tempdf))
    df = df.append(tempdf)
    time.sleep(2)

df.head(20)
# Out:
# 2019-02-12
# 17
# 2019-02-10
# 21
# 2019-02-07
# 18
# 2019-02-05
# 19
# 2019-02-02
# 25
#    GROUP_SET                                GROUP_ID  \
# 0    Lineups    -2544-201580-203493-1627742-1628398-
# 1    Lineups    -2544-200765-203493-1627742-1628398-
# 2    Lineups    -2544-200765-203484-1627742-1628398-
# 3    Lineups     -2544-200765-203484-203493-1628398-
# 4    Lineups     -2544-200765-202362-203484-1629021-
# 5    Lineups     -2544-202362-203484-203493-1628398-
# 6    Lineups     -2544-200765-203484-203493-1627742-
# 7    Lineups     -2544-200765-202362-203484-1627742-
# 8    Lineups    -200765-201580-202362-203484-203493-
# 9    Lineups  -200765-202362-203484-1627742-1629021-
# 10   Lineups  -200765-202362-203493-1627742-1628398-
# 11   Lineups      -2544-200765-202362-203484-203493-
# 12   Lineups    -2544-202362-203493-1627742-1628398-
# 13   Lineups     -2544-201580-202362-203493-1627742-
# 14   Lineups     -2544-202362-203484-203493-1627742-
# 15   Lineups     -2544-202362-203484-203493-1629021-
# 16   Lineups      -2544-200765-201580-203484-203493-
# 0    Lineups    -2544-201580-203493-1627742-1628398-
# 1    Lineups      -2199-2544-203493-1627742-1628398-
# 2    Lineups    -2544-203484-203493-1627742-1628398-
#
#                                            GROUP_NAME  GP  W  L  W_PCT  \
# 0   L. James - J. McGee - R. Bullock - B. Ingram -...   1  0  1    0.0
# 1   L. James - R. Rondo - R. Bullock - B. Ingram -...   1  0  1    0.0
# 2   L. James - R. Rondo - K. Caldwell-Pope - B. In...   1  0  1    0.0
# 3   L. James - R. Rondo - K. Caldwell-Pope - R. Bu...   1  0  1    0.0
# 1   Lineups  -2544-200765-203493-1627742-1628398-
# 2   Lineups  -2544-200765-203484-1627742-1628398-
# 3   Lineups   -2544-200765-203484-203493-1628398-
# 4   Lineups   -2544-200765-202362-203484-1629021-
#
#                                           GROUP_NAME  GP  W  L  W_PCT  \
# 0  L. James - J. McGee - R. Bullock - B. Ingram -...   1  0  1    0.0
# 1  L. James - R. Rondo - R. Bullock - B. Ingram -...   1  0  1    0.0
# 2  L. James - R. Rondo - K. Caldwell-Pope - B. In...   1  0  1    0.0
# 3  L. James - R. Rondo - K. Caldwell-Pope - R. Bu...   1  0  1    0.0
# 4  L. James - R. Rondo - L. Stephenson - K. Caldw...   1  0  1    0.0
#
#          MIN  FGM  FGA  ...  REB  AST  TOV  STL  BLK  BLKA  PF  PFD  PTS  \
# 0  11.316667   11   21  ...   13    6  5.0    0    2     1   6    6   27
# 1   9.616667    8   18  ...    9    6  4.0    3    0     0   7    3   22
# 2   5.083333    2    9  ...    4    0  2.0    1    1     1   3    5    6
# 3   4.733333    4   13  ...    6    3  1.0    0    0     1   3    0   10
# 4   3.716667    3    7  ...    3    1  2.0    0    0     0   0    2    9
#
#    PLUS_MINUS
# 0        -7.0
# 1         3.0
# 2        -1.0
# 3        -4.0
# 4        -5.0
#
# [5 rows x 29 columns]

# %%
#from nba_api.stats.endpoints import teamplayerdashboard
#trial = teamplayerdashboard.TeamPlayerDashboard(lakers_id,date_from_nullable = date, date_to_nullable = date, measure_type_detailed_defense = "Advanced").get_data_frames()[1]
#trial.head()

#from nba_api.stats.endpoints import playerdashboardbygeneralsplits
#trial1 = playerdashboardbygeneralsplits.PlayerDashboardByGeneralSplits('2544', measure_type_detailed = "Advanced").get_data_frames()[1]
#trial1.head()

from nba_api.stats.endpoints import commonplayerinfo
trial2 = commonplayerinfo.CommonPlayerInfo('2544').get_data_frames()[1]
trial2.head()
# Out:
# ['GROUP_SET', 'PLAYER_ID', 'PLAYER_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'eOFF_RATING', 'OFF_RATING', 'sp_work_OFF_RATING', 'eDEF_RATING', 'DEF_RATING', 'sp_work_DEF_RATING', 'eNET_RATING', 'NET_RATING', 'sp_work_NET_RATING', 'AST_PCT', 'AST_TO', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT', 'ePACE', 'PACE', 'sp_work_PACE', 'PIE', 'FGM', 'FGA', 'FGM_PG', 'FGA_PG', 'FG_PCT', 'GP_RANK', 'W_RANK', 'L_RANK', 'W_PCT_RANK', 'MIN_RANK', 'eOFF_RATING_RANK', 'OFF_RATING_RANK', 'sp_work_OFF_RATING_RANK', 'eDEF_RATING_RANK', 'DEF_RATING_RANK', 'sp_work_DEF_RATING_RANK', 'eNET_RATING_RANK', 'NET_RATING_RANK', 'sp_work_NET_RATING_RANK', 'AST_PCT_RANK', 'AST_TO_RANK', 'AST_RATIO_RANK', 'OREB_PCT_RANK', 'DREB_PCT_RANK', 'REB_PCT_RANK', 'TM_TOV_PCT_RANK', 'EFG_PCT_RANK', 'TS_PCT_RANK', 'USG_PCT_RANK', 'ePACE_RANK', 'PACE_RANK', 'sp_work_PACE_RANK', 'PIE_RANK', 'FGM_RANK', 'FGA_RANK', 'FGM_PG_RANK', 'FGA_PG_RANK', 'FG_PCT_RANK']
#    PLAYER_ID   PLAYER_NAME TimeFrame   PTS  AST  REB    PIE
# 0       2544  LeBron James   2018-19  26.8  7.6  8.6  0.192
